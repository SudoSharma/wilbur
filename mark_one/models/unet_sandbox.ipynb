# %% [markdown]
# ## Sandbox for Implementing U-Net

# %% [markdown]
# Practice training runs on complex deep networks and experiment semantic segmentation pipelines. Includes implementation of U-Net as basis for studying skip connections and to motivate a future analysis of Feature Pyramid Networks and RetinaNet.

# %% [markdown]
# ## General Approach
#
# 1. Download Cell Segmentation data
# - Build and train U-Net
# - Download CamVid
# - Train U-Net
# - Download COCO
# - Build and train FPN
# - Build and train RetinaNet

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.vision import *
from fastai.datasets import *
from fastai.callbacks import *

# %% [markdown]
# ## Glioblastoma-Astrocytoma and HeLa Cells

# %% [markdown]
# In order to download these datasets, I had to register with the [original distributor](http://celltrackingchallenge.net/) and obtain a login. When you first obtain the data, you'll notice that there are two time-lapse sequences for each cell-type, only a fraction of which are actually labelled for segmentation.

# %%
glioma_path = Path('/home/sudosharma/projects/data/glioma')
hela_path = Path('/home/sudosharma/projects/data/hela')
glioma_path.ls(), hela_path.ls()
# Out:
# ([PosixPath('/home/sudosharma/projects/data/glioma/02'),
#   PosixPath('/home/sudosharma/projects/data/glioma/models'),
#   PosixPath('/home/sudosharma/projects/data/glioma/02_GT'),
#   PosixPath('/home/sudosharma/projects/data/glioma/01'),
#   PosixPath('/home/sudosharma/projects/data/glioma/01_GT')],
#  [PosixPath('/home/sudosharma/projects/data/hela/02'),
#   PosixPath('/home/sudosharma/projects/data/hela/models'),
#   PosixPath('/home/sudosharma/projects/data/hela/02_GT'),
#   PosixPath('/home/sudosharma/projects/data/hela/01'),
#   PosixPath('/home/sudosharma/projects/data/hela/01_GT')])

# %% [markdown]
# In order to sample only the segmented files and their corresponding raw images without missing any files with the same name in a DIFFERENT folder, I had to rename all files by appending a '1' or a '2' as follows. (ex: man_seg005.tif --> 1man_seg005.tif). Very confusing...quite annoying.

# %%
(glioma_path/'01_GT'/'SEG').ls()
# Out:
# [PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg005.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg112.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg072.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg007.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg075.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg100.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg049.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg006.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg067.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg102.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg001.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg096.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg021.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg059.tif'),
#  PosixPath('/home/sudosharma/projects/data/glioma/01_GT/SEG/1man_seg092.tif')]

# %%
class BinarySegmentationLabelList(SegmentationLabelList):
    """Convert multi-instance label to background vs. cell binary segmentation."""
    def open(self, fn):
        mask = open_mask(fn)
        mask.px = (mask.px.sigmoid()>0.5).float()
        return mask

# %%
def get_img_lbls(path, seq):
    """Obtain the corresponding label for each image that actually has a segmented counterpart."""
    lbl = [l.name[-7:-4] for l in (path/f'0{seq}_GT'/'SEG').ls()]
    img = [i.name for i in (path/f'0{seq}').ls() if i.name[-7:-4] in lbl]
    return img

def get_data(path, sz=512, bs=1):
    """Create data loader with different batch sizes and size of image."""
    ifiles = get_img_lbls(path, 1) + get_img_lbls(path, 2)
    get_y_fn_base = lambda path, o: path/f'0{o.stem[0]}_GT'/'SEG'/f'{o.stem[0]}man_seg{o.stem[-3:]}{o.suffix}'
    get_y_fn = partial(get_y_fn_base, path)
    return (SegmentationItemList
            .from_folder(path)
            .filter_by_folder(include=['01', '02'])
            .filter_by_func(lambda fname: fname.name in ifiles)
            .split_by_rand_pct(0.1)
            .label_from_func(get_y_fn, label_cls=BinarySegmentationLabelList, classes=np.array(['back', 'cell']))
            .transform(get_transforms(flip_vert=True, max_warp=0.5), tfm_y=True, size=sz)
            .databunch(bs=bs))

def get_weights(data):
    """Obtain weights to balance class frequencies."""
    data_balance = (torch.stack([f[1].data.sum()for f in data.train_ds])
                    .float()/(512*512)).sum()/len(data.train_ds)
    return torch.stack([data_balance, (1-data_balance)])

# %%
glioma, hela = get_data(glioma_path), get_data(hela_path)
glioma_weights, hela_weights = get_weights(glioma), get_weights(hela)

# %%
glioma_weights, hela_weights
# Out:
# (tensor([0.0632, 0.9368]), tensor([0.4946, 0.5054]))

# %%
glioma.show_batch(1); hela.show_batch(1)

# %%
x, y = next(iter(glioma.train_dl))

# %%
x.shape, y.shape
# Out:
# (torch.Size([1, 3, 512, 512]), torch.Size([1, 1, 512, 512]))

# %% [markdown]
# ## U-Net

# %%
class SaveMaps():
    """Save feature maps from contraction phase of unet after second convolution."""
    def __init__(self, m):
        self.hook = m.register_forward_hook(self.hook_fn)
        
    def hook_fn(self, module, input, output): self.map = output
    def remove(self): self.hook.remove()

        
@dataclass
class SqueezeTarget(LearnerCallback):
    """Callback for adjusting target tensor shape for calculating cross entropy."""
    learn: Learner
    def on_batch_begin(self, **kwargs):
        lt = kwargs['last_target']
        return {'last_target': lt.squeeze(1)}
    
    
def iou(input, targs, classes):
    """Custom intersection-over-union metric for multi-class segmentation."""
    n = targs.shape[0]
    input = input.argmax(dim=1).view(n, -1)
    targs = targs.contiguous().view(n, -1)
    inp = torch.stack([input==i for i in range(classes)]).cuda()
    tar = torch.stack([targs==i for i in range(classes)]).cuda()
    intersect = lambda a, b: (a*b).sum().float()
    union = lambda a, b: (a+b).sum().float()
    return torch.stack([intersect(a, b)/union(a, b) for a, b in zip(inp, tar)]).sum() / classes

# %%
def conv(ic, oc, k=3, s=1, p=0, actn=True):
    """Conv and optional activation."""
    layers = [nn.Conv2d(ic, oc, k, stride=s, padding=p)]
    if actn: layers.append(nn.ReLU(True))
    return nn.Sequential(*layers).cuda()


def conv_block(ic, oc, transpose=False, maxpool=True): 
    """Two conv block with optional conv transpose and maxpool modules."""
    layers = [conv(ic, oc, p=1), conv(oc, oc, p=1)]
    if transpose: layers.append(nn.ConvTranspose2d(oc, oc//2, 2, stride=2))
    if maxpool: layers.append(nn.MaxPool2d(2, stride=2))
    return nn.Sequential(*layers).cuda()


def unet_down(cs): 
    """Downward contraction pathway of UNet."""
    layers = [conv_block(cs[i], cs[i+1]) for i in range(len(cs)-2)]
    layers.append(conv_block(cs[-2], cs[-1], transpose=True, maxpool=False))
    return nn.Sequential(*layers).cuda()


def unet_up(cs):
    """Upward expansion pathway of UNet."""
    cs.reverse()
    cs.pop()
    layers = [conv_block(cs[i], cs[i+1], transpose=True, maxpool=False) for i in range(len(cs)-2)]
    layers.append(conv_block(cs[-2], cs[-1], transpose=False, maxpool=False))
    return nn.ModuleList(layers)


class UNet(nn.Module):
    """UNet module with down path, up path, and cross connections using saved feature maps."""
    def __init__(self, channels, classes):
        super().__init__()
        self.unet_down = unet_down(channels)
        self.unet_up = unet_up(channels)
        self.drop_conv = nn.Sequential(conv(channels[-1], classes, k=1, actn=False), nn.Dropout(0.1, True))
        self.maps = [SaveMaps(block[-2]) for block in children(self.unet_down)]
        self.maps.pop()
        self.maps.reverse()

    def forward(self, x): 
        """Concatenate features maps from corresponding convolution+relu outputs in up/down paths."""
        x = self.unet_down(x)
        for i, m in enumerate(self.unet_up):
            x = torch.cat([self.maps[i].map, x], dim=1)
            x = m(x)
        return self.drop_conv(x)
    
    def close(self): 
        for mp in self.maps: mp.remove()

# %%
channels = [3, 64, 128, 256, 512]
classes = glioma.c
model = UNet(channels, classes)

# %%
learn = Learner(glioma, 
                model, 
                metrics=partial(iou, classes=classes), 
                opt_func=partial(torch.optim.SGD, momentum=0.99),
                loss_func=partial(F.cross_entropy, weight=glioma_balance.cuda()),
                callback_fns=[SqueezeTarget])
learn.init(nn.init.kaiming_normal_)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
callbacks = [
    SaveModelCallback(learn, monitor='iou', mode='max', name='unet'), 
    TerminateOnNaNCallback(), 
    GradientClipping(learn, clip=0.1),
    ReduceLROnPlateauCallback(learn, patience=50, min_delta=0.01)]
learn.callbacks.extend(callbacks)

# %%
learn.fit(500, 1e-3)
# Out:
# Total time: 30:43 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>iou</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.121793</td>
#       <td>0.844271</td>
#       <td>0.243738</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.887996</td>
#       <td>0.704539</td>
#       <td>0.152330</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.781075</td>
#       <td>0.727056</td>
#       <td>0.025083</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.744843</td>
#       <td>0.737503</td>
#       <td>0.023702</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.723333</td>
#       <td>0.708876</td>
#       <td>0.023732</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.703403</td>
#       <td>0.685958</td>
#       <td>0.024984</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.689462</td>
#       <td>0.673863</td>
#       <td>0.108170</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.678589</td>
#       <td>0.662673</td>
#       <td>0.253504</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.667680</td>
#       <td>0.660155</td>
#       <td>0.037701</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.649086</td>
#       <td>0.647282</td>
#       <td>0.029815</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.638036</td>
#       <td>0.621448</td>
#       <td>0.054870</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.613453</td>
#       <td>0.575837</td>
#       <td>0.356190</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.587322</td>
#       <td>0.544676</td>
#       <td>0.341959</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.555941</td>
#       <td>0.510043</td>
#       <td>0.330965</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.512918</td>
#       <td>0.441002</td>
#       <td>0.369576</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.474452</td>
#       <td>0.410144</td>
#       <td>0.355782</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.423200</td>
#       <td>0.348382</td>
#       <td>0.365537</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.374297</td>
#       <td>0.312596</td>
#       <td>0.370106</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.339254</td>
#       <td>0.329626</td>
#       <td>0.339499</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.307011</td>
#       <td>0.270877</td>
#       <td>0.364423</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.283415</td>
#       <td>0.262931</td>
#       <td>0.364639</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.261910</td>
#       <td>0.270655</td>
#       <td>0.368859</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.256220</td>
#       <td>0.278597</td>
#       <td>0.348467</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.271734</td>
#       <td>0.271686</td>
#       <td>0.372336</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.279994</td>
#       <td>0.258503</td>
#       <td>0.371906</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.277320</td>
#       <td>0.249108</td>
#       <td>0.370782</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.291261</td>
#       <td>0.245586</td>
#       <td>0.371628</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.295155</td>
#       <td>0.292238</td>
#       <td>0.341587</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.301144</td>
#       <td>0.356191</td>
#       <td>0.379506</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.292451</td>
#       <td>0.374010</td>
#       <td>0.315992</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.286225</td>
#       <td>0.333691</td>
#       <td>0.378394</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.299840</td>
#       <td>0.236650</td>
#       <td>0.363306</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.275023</td>
#       <td>0.242204</td>
#       <td>0.358174</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.319585</td>
#       <td>0.274133</td>
#       <td>0.371803</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.295626</td>
#       <td>0.332244</td>
#       <td>0.325024</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.338007</td>
#       <td>0.320173</td>
#       <td>0.375893</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.330272</td>
#       <td>0.311577</td>
#       <td>0.333045</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.305093</td>
#       <td>0.322813</td>
#       <td>0.376138</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.270874</td>
#       <td>0.236062</td>
#       <td>0.357558</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.263523</td>
#       <td>0.235171</td>
#       <td>0.369285</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.243425</td>
#       <td>0.341243</td>
#       <td>0.380196</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.266305</td>
#       <td>0.249205</td>
#       <td>0.348913</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.254730</td>
#       <td>0.241509</td>
#       <td>0.374584</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.259516</td>
#       <td>0.280190</td>
#       <td>0.377552</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.237375</td>
#       <td>0.226675</td>
#       <td>0.371739</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.237885</td>
#       <td>0.291204</td>
#       <td>0.332107</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.265481</td>
#       <td>0.440882</td>
#       <td>0.382640</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.283990</td>
#       <td>0.351900</td>
#       <td>0.314980</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.269680</td>
#       <td>0.287865</td>
#       <td>0.375944</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.251500</td>
#       <td>0.224659</td>
#       <td>0.366931</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.236218</td>
#       <td>0.216272</td>
#       <td>0.366048</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.241218</td>
#       <td>0.228163</td>
#       <td>0.373765</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.226329</td>
#       <td>0.216298</td>
#       <td>0.368661</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.227468</td>
#       <td>0.251190</td>
#       <td>0.375203</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.228884</td>
#       <td>0.233258</td>
#       <td>0.372188</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.225352</td>
#       <td>0.214123</td>
#       <td>0.362610</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.231184</td>
#       <td>0.234243</td>
#       <td>0.374086</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.218307</td>
#       <td>0.256184</td>
#       <td>0.378645</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.223680</td>
#       <td>0.261079</td>
#       <td>0.336544</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.230596</td>
#       <td>0.208713</td>
#       <td>0.361633<
# Better model found at epoch 0 with iou value: 0.24373824894428253.
# Better model found at epoch 7 with iou value: 0.2535043954849243.
# Better model found at epoch 11 with iou value: 0.35619020462036133.
# Better model found at epoch 14 with iou value: 0.36957624554634094.
# Better model found at epoch 17 with iou value: 0.3701060712337494.
# Better model found at epoch 23 with iou value: 0.372335821390152.
# Better model found at epoch 28 with iou value: 0.37950578331947327.
# Better model found at epoch 40 with iou value: 0.38019582629203796.
# Better model found at epoch 46 with iou value: 0.38264039158821106.
# Better model found at epoch 60 with iou value: 0.3841007649898529.
# Better model found at epoch 76 with iou value: 0.38865146040916443.
# Better model found at epoch 98 with iou value: 0.3920952379703522.
# Better model found at epoch 103 with iou value: 0.3931356966495514.
# Better model found at epoch 122 with iou value: 0.39641430974006653.
# Better model found at epoch 125 with iou value: 0.3974252939224243.
# Better model found at epoch 128 with iou value: 0.40006521344184875.
# Better model found at epoch 130 with iou value: 0.4049844741821289.
# Better model found at epoch 139 with iou value: 0.4064505100250244.
# Better model found at epoch 145 with iou value: 0.41554856300354004.
# Better model found at epoch 148 with iou value: 0.4218226969242096.
# Better model found at epoch 186 with iou value: 0.4293995201587677.
# Better model found at epoch 196 with iou value: 0.43269339203834534.
# Better model found at epoch 236 with iou value: 0.4339046776294708.
# Better model found at epoch 239 with iou value: 0.4346500337123871.
# Better model found at epoch 261 with iou value: 0.4359266757965088.
# Better model found at epoch 278 with iou value: 0.4359966218471527.
# Better model found at epoch 293 with iou value: 0.4383537769317627.
# Better model found at epoch 304 with iou value: 0.4385751485824585.
# Epoch 307: reducing lr to 0.0002
# Better model found at epoch 329 with iou value: 0.4389837086200714.
# Epoch 358: reducing lr to 4e-05
# Epoch 409: reducing lr to 8.000000000000001e-06
# Epoch 460: reducing lr to 1.6000000000000004e-06

# %%
learn.recorder.plot_losses()

# %%
learn.show_results()

# %% [markdown]
# ## CamVid

# %%
path = untar_data(URLs.CAMVID)
path_lbl = path/'labels'
path_img = path/'images'
codes = np.loadtxt(path/'codes.txt', dtype=str)
codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %%
def get_data(sz=256, bs=32, path_img=path_img, path_lbl=path_lbl, codes=codes):
    """Create data loader with different batch sizes and size of image."""
    get_y_fn = lambda o: path_lbl/f'{o.stem}_P{o.suffix}'
    return (SegmentationItemList.from_folder(path_img)
            .split_by_rand_pct()
            .label_from_func(get_y_fn, classes=codes)
            .transform(get_transforms(), tfm_y=True, size=sz)
            .databunch(bs=bs)
            .normalize(imagenet_stats))

def get_weights():
    # TODO:
    # sum up pixels for each class across all training data, divide by total pixels in all training data
    # calculate inverse class frequency (1/class freqency)
    # normalize to add up to 1: (1/class_frequencey)/(1/class_frequency).sum()

# %%
data = get_data()
data.show_batch(2)

# %%
channels = [3, 64, 128, 256, 512, 1024]
classes = len(data.classes)
model = UNet(channels, classes)

# %%
learn = Learner(data, 
                model, 
                metrics=[partial(iou, classes=classes)], 
                opt_func=partial(torch.optim.SGD, momentum=0.99),
                loss_func=F.cross_entropy,
                callback_fns=[SqueezeTarget])
learn.init(nn.init.kaiming_normal_)

# %%
learn.lr_find(start_lr=1e-3, end_lr=1e3)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
callbacks = [
    SaveModelCallback(learn, monitor='iou', mode='max', name='unet'), 
    TerminateOnNaNCallback(), 
    GradientClipping(learn, clip=0.1),
    ReduceLROnPlateauCallback(learn, patience=50, min_delta=0.001)]
learn.callbacks.extend(callbacks)

# %%
learn.fit(1500, 1e-2)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1478' class='' max='1500', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       98.53% [1478/1500 8:30:10<07:35]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>iou</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.336361</td>
#       <td>3.227644</td>
#       <td>0.068481</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.432487</td>
#       <td>2.429641</td>
#       <td>0.227241</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.941198</td>
#       <td>2.370772</td>
#       <td>0.177433</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.684415</td>
#       <td>2.099101</td>
#       <td>0.245733</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.473808</td>
#       <td>2.029494</td>
#       <td>0.249913</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.306423</td>
#       <td>1.895032</td>
#       <td>0.260178</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.166724</td>
#       <td>1.759534</td>
#       <td>0.264124</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.035883</td>
#       <td>1.651581</td>
#       <td>0.288088</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.920136</td>
#       <td>1.568310</td>
#       <td>0.292792</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.820649</td>
#       <td>1.505368</td>
#       <td>0.298399</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.737577</td>
#       <td>1.460695</td>
#       <td>0.297178</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.663955</td>
#       <td>1.411363</td>
#       <td>0.303094</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.603186</td>
#       <td>1.375692</td>
#       <td>0.307530</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.549052</td>
#       <td>1.345527</td>
#       <td>0.310764</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.498891</td>
#       <td>1.339943</td>
#       <td>0.308597</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.457910</td>
#       <td>1.288034</td>
#       <td>0.319965</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.415476</td>
#       <td>1.256688</td>
#       <td>0.319631</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.374365</td>
#       <td>1.225245</td>
#       <td>0.325075</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.337861</td>
#       <td>1.194818</td>
#       <td>0.325354</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.305958</td>
#       <td>1.174178</td>
#       <td>0.328929</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.280891</td>
#       <td>1.156233</td>
#       <td>0.329082</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.258584</td>
#       <td>1.158796</td>
#       <td>0.328317</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.241921</td>
#       <td>1.179796</td>
#       <td>0.325460</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.227929</td>
#       <td>1.149776</td>
#       <td>0.329317</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.204926</td>
#       <td>1.094726</td>
#       <td>0.334325</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.188381</td>
#       <td>1.108839</td>
#       <td>0.333349</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.177718</td>
#       <td>1.089593</td>
#       <td>0.335874</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.159600</td>
#       <td>1.079314</td>
#       <td>0.337372</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.143447</td>
#       <td>1.060722</td>
#       <td>0.339024</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.135147</td>
#       <td>1.065991</td>
#       <td>0.339003</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.121869</td>
#       <td>1.047355</td>
#       <td>0.341590</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.117362</td>
#       <td>1.049829</td>
#       <td>0.339121</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.126989</td>
#       <td>1.031993</td>
#       <td>0.342498</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.127532</td>
#       <td>1.062078</td>
#       <td>0.339574</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.116902</td>
#       <td>1.010613</td>
#       <td>0.346232</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.102366</td>
#       <td>1.005172</td>
#       <td>0.345193</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.087530</td>
#       <td>1.005271</td>
#       <td>0.348658</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.076395</td>
#       <td>0.983891</td>
#       <td>0.351492</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.059984</td>
#       <td>0.972860</td>
#       <td>0.355107</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.049731</td>
#       <td>0.974588</td>
#       <td>0.353722</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.041112</td>
#       <td>0.975727</td>
#       <td>0.358886</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.032277</td>
#       <td>0.969831</td>
#       <td>0.355594</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.034177</td>
#       <td>1.018526</td>
#       <td>0.352431</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.038948</td>
#       <td>0.959959</td>
#       <td>0.358179</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.051370</td>
#       <td>1.002807</td>
#       <td>0.353573</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.050684</td>
#       <td>0.970556</td>
#       <td>0.359067</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.035282</td>
#       <td>0.956170</td>
#       <td>0.354159</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.023035</td>
#       <td>0.943602</td>
#       <td>0.357361</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.013904</td>
#       <td>0.926975</td>
#       <td>0.367234</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.000757</td>
#       <td>0.914540</td>
#       <td>0.369219</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.989560</td>
#       <td>0.906011</td>
#       <td>0.369364</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.986261</td>
#       <td>0.947791</td>
#       <td>0.365189</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.990047</td>
#       <td>0.973595</td>
#       <td>0.360841</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.990683</td>
#       <td>0.922943</td>
#       <td>0.368791</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.982690</td>
#       <td>0.900930</td>
#       <td>0.
# Better model found at epoch 0 with iou value: 0.06848139315843582.
# Better model found at epoch 1 with iou value: 0.22724059224128723.
# Better model found at epoch 3 with iou value: 0.24573282897472382.
# Better model found at epoch 4 with iou value: 0.24991324543952942.
# Better model found at epoch 5 with iou value: 0.26017773151397705.
# Better model found at epoch 6 with iou value: 0.26412445306777954.
# Better model found at epoch 7 with iou value: 0.2880876958370209.
# Better model found at epoch 8 with iou value: 0.2927919030189514.
# Better model found at epoch 9 with iou value: 0.2983987033367157.
# Better model found at epoch 11 with iou value: 0.3030937612056732.
# Better model found at epoch 12 with iou value: 0.3075300455093384.
# Better model found at epoch 13 with iou value: 0.3107638359069824.
# Better model found at epoch 15 with iou value: 0.3199651539325714.
# Better model found at epoch 17 with iou value: 0.32507503032684326.
# Better model found at epoch 18 with iou value: 0.3253543972969055.
# Better model found at epoch 19 with iou value: 0.3289293646812439.
# Better model found at epoch 20 with iou value: 0.3290815055370331.
# Better model found at epoch 23 with iou value: 0.3293170928955078.
# Better model found at epoch 24 with iou value: 0.33432453870773315.
# Better model found at epoch 26 with iou value: 0.3358738422393799.
# Better model found at epoch 27 with iou value: 0.337371826171875.
# Better model found at epoch 28 with iou value: 0.3390235900878906.
# Better model found at epoch 30 with iou value: 0.3415902853012085.
# Better model found at epoch 32 with iou value: 0.34249845147132874.
# Better model found at epoch 34 with iou value: 0.34623199701309204.
# Better model found at epoch 36 with iou value: 0.3486579358577728.
# Better model found at epoch 37 with iou value: 0.35149237513542175.
# Better model found at epoch 38 with iou value: 0.35510650277137756.
# Better model found at epoch 40 with iou value: 0.3588859438896179.
# Better model found at epoch 45 with iou value: 0.35906654596328735.
# Better model found at epoch 48 with iou value: 0.3672339916229248.
# Better model found at epoch 49 with iou value: 0.36921870708465576.
# Better model found at epoch 50 with iou value: 0.3693636357784271.
# Better model found at epoch 55 with iou value: 0.3702438771724701.
# Better model found at epoch 56 with iou value: 0.3713533580303192.
# Better model found at epoch 57 with iou value: 0.3761961758136749.
# Better model found at epoch 59 with iou value: 0.378202885389328.
# Better model found at epoch 62 with iou value: 0.3802696764469147.
# Better model found at epoch 69 with iou value: 0.382200688123703.
# Better model found at epoch 75 with iou value: 0.3849037289619446.
# Better model found at epoch 80 with iou value: 0.38493913412094116.
# Better model found at epoch 81 with iou value: 0.3904588520526886.
# Better model found at epoch 86 with iou value: 0.39225274324417114.
# Better model found at epoch 88 with iou value: 0.3933907151222229.
# Better model found at epoch 90 with iou value: 0.39497867226600647.
# Better model found at epoch 96 with iou value: 0.396081805229187.
# Better model found at epoch 101 with iou value: 0.3975868821144104.
# Better model found at epoch 105 with iou value: 0.3992488980293274.
# Better model found at epoch 111 with iou value: 0.40198779106140137.
# Better model found at epoch 125 with iou value: 0.40275803208351135.
# Better model found at epoch 131 with iou value: 0.40332111716270447.
# Better model found at epoch 132 with iou value: 0.4043269157409668.
# Better model found at epoch 133 with iou value: 0.4057742953300476.
# Better model found at epoch 138 with iou value: 0.40686824917793274.
# Better model found at epoch 142 with iou value: 0.4071234464645386.
# Better model found at epoch 146 with iou value: 0.40739011764526367.
# Better model found at epoch 147 with iou value: 0.4074832499027252.
# Better model found at epoch 148 with iou value: 0.40833330154418945.
# Better model found at epoch 149 with iou value: 0.40851297974586487.
# Better model found at epoch 151 with iou value: 0.4100378453731537.
# Better model found at epoch 153 with iou value: 0.4103359878063202.
# Better model found at epoch 164 with iou value: 0.4109501540660858.
# Better model found at epoch 168 with iou value: 0.4117094874382019.
# Better model found at epoch 172 with iou value: 0.41176551580429077.
# Better model found at epoch 173 with iou value: 0.41318848729133606.
# Better model found at epoch 176 with iou value: 0.4135127067565918.
# Better model found at epoch 188 with iou value: 0.4136793911457062.
# Better model found at epoch 190 with iou value: 0.4138636589050293.
# Better model found at epoch 207 with iou value: 0.4140431582927704.
# Better model found at epoch 212 with iou value: 0.41424956917762756.
# Better model found at epoch 214 with iou value: 0.4146066904067993.
# Better model found at epoch 219 with iou value: 0.41507667303085327.
# Better model found at epoch 225 with iou value: 0.416979044675827.
# Better model found at epoch 256 with iou value: 0.4177059233188629.
# Better model found at epoch 261 with iou value: 0.4178212881088257.
# Better model found at epoch 266 with iou value: 0.41885921359062195.
# Better model found at epoch 267 with iou value: 0.4188849925994873.
# Better model found at epoch 281 with iou value: 0.4189970791339874.
# Better model found at epoch 284 with iou value: 0.41920846700668335.
# Better model found at epoch 288 with iou value: 0.41982901096343994.
# Better model found at epoch 295 with iou value: 0.42038148641586304.
# Better model found at epoch 298 with iou value: 0.4208472669124603.
# Better model found at epoch 312 with iou value: 0.4208734929561615.
# Better model found at epoch 315 with iou value: 0.4217403829097748.
# Better model found at epoch 316 with iou value: 0.4221322238445282.
# Better model found at epoch 319 with iou value: 0.42226508259773254.
# Better model found at epoch 321 with iou value: 0.42289602756500244.
# Better model found at epoch 329 with iou value: 0.4234083592891693.
# Better model found at epoch 359 with iou value: 0.42358627915382385.
# Better model found at epoch 367 with iou value: 0.42441606521606445.
# Better model found at epoch 393 with iou value: 0.4258663058280945.
# Better model found at epoch 400 with iou value: 0.42592620849609375.
# Better model found at epoch 414 with iou value: 0.4260536730289459.
# Better model found at epoch 455 with iou value: 0.42657819390296936.
# Better model found at epoch 464 with iou value: 0.426659494638443.
# Better model found at epoch 469 with iou value: 0.4267258644104004.
# Better model found at epoch 470 with iou value: 0.4273066818714142.
# Better model found at epoch 474 with iou value: 0.42734450101852417.
# Better model found at epoch 478 with iou value: 0.42785730957984924.
# Better model found at epoch 480 with iou value: 0.42876994609832764.
# Better model found at epoch 484 with iou value: 0.4290367662906647.
# Better model found at epoch 498 with iou value: 0.4291006326675415.
# Better model found at epoch 518 with iou value: 0.4291401505470276.
# Better model found at epoch 520 with iou value: 0.4294184446334839.
# Better model found at epoch 523 with iou value: 0.42997780442237854.
# Better model found at epoch 543 with iou value: 0.43021196126937866.
# Better model found at epoch 548 with iou value: 0.4304470121860504.
# Better model found at epoch 553 with iou value: 0.4305459260940552.
# Better model found at epoch 558 with iou value: 0.43067753314971924.
# Better model found at epoch 561 with iou value: 0.43074148893356323.
# Better model found at epoch 565 with iou value: 0.4310509264469147.
# Better model found at epoch 568 with iou value: 0.4312760531902313.
# Better model found at epoch 598 with iou value: 0.43138062953948975.
# Better model found at epoch 643 with iou value: 0.4317360520362854.
# Better model found at epoch 649 with iou value: 0.4318968653678894.
# Epoch 649: reducing lr to 0.002
# Better model found at epoch 650 with iou value: 0.43205392360687256.
# Better model found at epoch 652 with iou value: 0.4321921169757843.
# Better model found at epoch 658 with iou value: 0.43254491686820984.
# Better model found at epoch 659 with iou value: 0.43259114027023315.
# Better model found at epoch 662 with iou value: 0.43278899788856506.
# Better model found at epoch 663 with iou value: 0.43298274278640747.
# Better model found at epoch 664 with iou value: 0.43312308192253113.
# Better model found at epoch 670 with iou value: 0.4332160949707031.
# Better model found at epoch 673 with iou value: 0.43342095613479614.
# Better model found at epoch 683 with iou value: 0.4335381090641022.
# Better model found at epoch 684 with iou value: 0.4337403476238251.
# Better model found at epoch 687 with iou value: 0.43377381563186646.
# Better model found at epoch 694 with iou value: 0.4340408444404602.
# Better model found at epoch 701 with iou value: 0.43404725193977356.
# Better model found at epoch 704 with iou value: 0.4342855215072632.
# Better model found at epoch 715 with iou value: 0.43433675169944763.
# Better model found at epoch 716 with iou value: 0.43441593647003174.
# Better model found at epoch 730 with iou value: 0.43446651101112366.
# Better model found at epoch 748 with iou value: 0.4346378743648529.
# Better model found at epoch 764 with iou value: 0.43471139669418335.
# Better model found at epoch 766 with iou value: 0.4348311722278595.
# Better model found at epoch 793 with iou value: 0.43492165207862854.
# Better model found at epoch 802 with iou value: 0.43504759669303894.
# Better model found at epoch 811 with iou value: 0.4350905418395996.
# Epoch 823: reducing lr to 0.0004
# Better model found at epoch 828 with iou value: 0.4352009892463684.
# Better model found at epoch 831 with iou value: 0.4353162348270416.
# Better model found at epoch 834 with iou value: 0.43541449308395386.
# Better model found at epoch 854 with iou value: 0.43542730808258057.
# Better model found at epoch 857 with iou value: 0.43545129895210266.
# Better model found at epoch 861 with iou value: 0.43547216057777405.
# Better model found at epoch 863 with iou value: 0.43551772832870483.
# Better model found at epoch 872 with iou value: 0.435735821723938.
# Epoch 914: reducing lr to 8e-05
# Better model found at epoch 919 with iou value: 0.4357544481754303.
# Better model found at epoch 925 with iou value: 0.4357805550098419.
# Better model found at epoch 936 with iou value: 0.43579721450805664.
# Better model found at epoch 983 with iou value: 0.43584585189819336.
# Epoch 987: reducing lr to 1.6000000000000003e-05
# Epoch 1038: reducing lr to 3.2000000000000007e-06
# Epoch 1089: reducing lr to 6.400000000000002e-07
# Epoch 1140: reducing lr to 1.2800000000000006e-07
# Epoch 1191: reducing lr to 2.5600000000000014e-08
# Epoch 1242: reducing lr to 5.120000000000003e-09
# Epoch 1293: reducing lr to 1.0240000000000006e-09
# Epoch 1344: reducing lr to 2.0480000000000014e-10
# Epoch 1395: reducing lr to 4.096000000000003e-11
# Epoch 1446: reducing lr to 8.192000000000007e-12
# Exception ignored in: <function _releaseLock at 0x7fe7320400d0>
# Traceback (most recent call last):
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/logging/__init__.py", line 221, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
# Traceback (most recent call last):
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
# Traceback (most recent call last):
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/sudosharma/miniconda3/envs/wilbur/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/wilbur/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 100                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     101                 if cb_handler.on_batch_end(loss): break
#
# ~/miniconda3/envs/wilbur/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      31     if opt is not None:
# ---> 32         loss,skip_bwd = cb_handler.on_backward_begin(loss)
#      33         if not skip_bwd:                     loss.backward()
#
# ~/miniconda3/envs/wilbur/lib/python3.7/site-packages/fastai/callback.py in on_backward_begin(self, loss)
#     288         "Handle gradient calculation on `loss`."
# --> 289         self.smoothener.add_value(loss.detach().cpu())
#     290         self.state_dict['last_loss'], self.state_dict['smooth_loss'] = loss, self.smoothener.smooth
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-3aaae2118456> in <module>
# ----> 1 learn.fit(1500, 1e-2)
#
# ~/miniconda3/envs/wilbur/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     194         callbacks = [cb(self) for cb in self.callback_fns] + listify(callbacks)
#     195         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# --> 196         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     197
#     198     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/miniconda3/envs/wilbur/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#     109         exception = e
#     110         raise
# --> 111     finally: cb_handler.on_train_end(exception)
#     112
#     113 loss_func_name2activ = {'cross_entropy_loss': F.softmax, 'nll_loss': torch.exp, 'poisson_nll_loss': torch.exp,
#
# ~/miniconda3/envs/wilbur/lib/python3.7/site-packages/fastai/callback.py in on_train_end(self, exception)
#     320     def on_train_end(self, exception:Union[bool,Exception])->None:
#     321         "Handle end of training, `exception` is an `Exception` or False if no exceptions during training."
# --> 322         self('train_end', exception=exception)
#     323
#     324 class AverageMetric(Callback):
#
# ~/miniconda3/envs/wilbur/lib/python3.7/site-packages/fastai/callback.py in __call__(self, cb_name, call_mets, **kwargs)
#     248         if call_mets:
#     249             for met in self.metrics: self._call_and_update(met, cb_name, **kwargs)
# --> 250         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
#     251
#     252     def set_dl(self, dl:DataLoader):
#
# ~/miniconda3/envs/wilbur/lib/python3.7/site-packages/fastai/callback.py in _call_and_update(self, cb, cb_name, **kwargs)
#     238     def _call_and_update(self, cb, cb_name, **kwargs)->None:
#     239         "Call `cb_name` on `cb` and update the inner state."
# --> 240         new = ifnone(getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs), dict())
#     241         for k,v in new.items():
#     242             if k not in self.state_dict:
#
# ~/miniconda3/envs/wilbur/lib/python3.7/site-packages/fastai/callbacks/tracker.py in on_train_end(self, **kwargs)
#     102         "Load the best model."
#     103         if self.every=="improvement" and (self.learn.path/f'{self.learn.model_dir}/{self.name}.pth').is_file():
# --> 104             self.learn.load(f'{self.name}', purge=False)
#     105
#     106 class ReduceLROnPlateauCallback(TrackerCallback):
#
# ~/miniconda3/envs/wilbur/lib/python3.7/site-packages/fastai/basic_train.py in load(self, name, device, strict, with_opt, purge, remove_module)
#     276             get_model(self.model).load_state_dict(state, strict=strict)
#     277         del state
# --> 278         gc.collect()
#     279         return self
#     280
#
# KeyboardInterrupt:

# %%
learn.recorder.plot_losses()

# %%
learn.show_results(rows=2)

# %% [markdown]
# ### U-Net Analysis on CamVid

# %% [markdown]
# I used the same optimizer as the origin paper, and the same general architecture. I added padding at the end of each convolution unlike in the paper, to preserve the output dimensions. This also make the upward path much easier to construct. Finally, I used similar data augmentation techniques and created a custom intersection-over-union metric for multi-class segmentation.
#
# <b>Why was not abe to get a higher IOU for this dataset?</b>
# - Could have maybe trained for more epochs?
# - Architecture not complex enough for CamVid?
# - Maybe pretrained network on ImageNet would do much better.
# - Maybe there's not enough data
# - In the U-Net paper they had a pre-computed weight map for each class to handle class imbalance, maybe if I added that the network would train faster/better.
#
# <b>Lessons:</b>
# - pay close attention to shapes of tensors that pytorch's built-in loss functions expect
# - modify tensor shapes using callbacks or forward hooks
# - sometimes the loss landscape is really flat at the beginning, so you might have to train a while before seeing any improvement.
# - fastai doesn't recursively put every pytorch module on the GPU, might have to do it manually
# - data augmentation can act as a form of regularization
# - multi-class problems have a class-imbalance issue, where certain classes can be overrepresented.
